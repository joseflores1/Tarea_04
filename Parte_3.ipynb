# %% [markdown]
# ### (a) ¿Qué tan aceptable son sus resultados? Justifique su respuesta haciendo referencia a los resultados reportados en la Parte 2

# %% [markdown]
# Entrenándo la red durante 10 épocas con la arquitectura que aparece en train.ipynb se lograron los siguientes resultados:
#
# Epoch: 10- Time:  8.36 - Train L1 Loss:  0.0168 - Validation L1 Loss: 0.2400 - Train RMSE: 0.0510 - Validation RMSE: 0.3922
#
# Obsérvese cómo la pérdida L1 y el RMSE para los datos de entrenamiento tiene un muchísimo mejor desempeño que para los datos de validación, lo que se refleja en el último gráfico realizado:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Nótese cómo el modelo pudo aprender a predecir de buena manera los datos de entrenamiento pero no tan así los de validación. El modelo no capta el gran crecimiento del valor de Close para la criptomoneda, es decir, pareciera no ser capaz de captar esa volatilidad que puede caracterizar a esta clase de currency. Por lo menos predice que el valor de la moneda se mantiene estable y que no disminuye abruptamente (el cual sería el peor caso, pues una persona que creyera en este modelo se vería "forzada" a vender sus bitcoins antes de que el precio cayera cuando la realidad es que este seguirá aumentando)

# %% [markdown]
# ### (b) ¿Qué tanto recomendar ́ıa el uso de su modelo a una persona que quiere comenzar a invertir en Bitcoin?

# %% [markdown]
# Se respondió algo de esto en la pregunta anterior. No se recomendaría especialmente el uso de este modelo porque no pudo captar bien la volatilidad o el gran crecimiento experimentado por la bitcoin en los últimos meses del año. Nuevamente, se hace hincapié en que por lo menos el modelo no "forzaría" al cliente a vender sus criptomonedas al no indicar una caída abrupta de precios (que es exactamente lo contrario a lo que realmente sucede). Además, es un modelo claramente simplificado y que fue realizado más para fines didáctico que para una posible implementación. Si fuera tan fácil como entrenar un modelo de este estilo en unos minutos para poder predecir el comportamiento de la bitcoin a través del tiempo, este "problema de predicción" no sería, valga la redundancia, un "problema" en sí.

# %% [markdown]
# ### (c) ¿Qué estrategias que no haya utilizado en su implementación agregaría a una futura implementación?

# %% [markdown]
# Una de las primeras ideas que se vienen a la mente es la de alterar la arquitectura a travpes de una búsqueda y optiimzación de hiperparámetros, como podrían ser el número de capas, la bidireccionalidad, el hidden_size, el optimizador, la función de pérdida, técnicas de regularización, el tamaño del embedding, el largo de las secuencias, la separación entre training y validation según otros factores, etc. Además, sería interesante obtener o utilizar nuevas variables para agregar más información al modelo, por ejemplo, el volumen de BTC fue una columna que se droppeó pero que podría entregar información relevante. También se destaca el horizonte de tiempo para el que se obtiene una secuencia, por ejemplo, para la tarea se definió un intervalo de 2 horas, lo que podría variar (esto está directametne relacionado con el largo de la secuencia)
#
# Una técnica adicional que podŕia ser de interés es la de un Moving Average, que permitiría posiblemente suavizar los valores y obtener tendencias subyacentes eliminando fluctuaciones o ruidos a corto plazo. Si bien es asimismo una técnica hiperparametrizable, pues habría que definir el tamaño de la ventana.
